# %%
## the declaration to a variable happens automatically when you assign a
## value to it

# %%
## assigning values to variables
age=23
height=5.3
name="Kajal"
is_student=True

##printing the variables
print(type(age))
print(type(height))
print("name:",name)
print(is_student)
# Out:
# <class 'int'>
# <class 'float'>
# name: Kajal
# True

# %%
## Naming Conventions

## variable names should be descriptive
## must ALWAYS start with a letter or an underscore (_)
## they may contain numbers, letters or underscore
## variable names are case sensitive

## valid variable names
first_name = "Kajal"
last_name = "Sanwal"

# %%
## invalid variable names
##2age=34
##first-name="kjl"

# %%
## case sensitivity
name = "Kajal"
Name = "Sakshi"

print(Name)

name == Name
# Out:
# Sakshi
# False

# %%
## understanding variable types
## python is dynamically typed, type of a variable is determined at runtime

# %%
## Type Checking and Conversion

height = 5.2
print(height)
print(type(height))

float(int(height))
# Out:
# 5.2
# <class 'float'>
# 5.0

# %%
## type conversion
agestr = str(age)

print(type(agestr))


age='24'
print(type(int(age)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Dynamic Typing
## python allows the type of a variable to change as the program executes

var=10
print(var, type(var))

var = "Kajal"
print(var,type(var))

var = 3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Kajal <class 'str'>
# 3.14 <class 'float'>

# %%
## input 

age = int(input("what is the age?"))
print(age,type(age))
# Out:
# 5 <class 'int'>

# %%
## simple calculator

num1 = float(input("enter first number: "))
num2 = float(input("enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1*num2
quotient = num1/num2

print("sum: ", sum)
print("difference: ", difference)
print("product: ", product)
print("quotient: ", quotient)
# Out:
# sum:  5.0
# difference:  1.0
# product:  6.0
# quotient:  1.5
