# %%
## Integer data type
age=23
type(age)
# Out:
# int

# %%
##floating data type
height=5.30
print(height)
print(type(height))
# Out:
# 5.3
# <class 'float'>

# %%
## string data type example
name = "kajal"
print(name)
print(type(name))
# Out:
# kajal
# <class 'str'>

# %%
## boolean data type
type(True)

is_True = True
print(type(is_True))

a=10
b=10
a==b
# Out:
# <class 'bool'>
# True

# %%
##common errors

#result = "Hello" + 5 #error

result = "Hello" + str(5)
print(result)
# Out:
# Hello5
